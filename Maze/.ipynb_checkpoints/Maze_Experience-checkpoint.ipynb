# %% [markdown]
# # Maze Experiment Introduction

# %% [markdown]
# In this notebook, we will be running the MDP_Model on the Maze problem. This 2D simulation builds on a `gym-maze` package that can be found here: https://github.com/MattChanTK/gym-maze. Before beginning this simulation, please be sure to install the relevant packages on the github **Installation** section (pygame and numpy are also required)!

# %% [markdown]
# ## Demonstration

# %% [markdown]
# First, a quick demonstration about what the game is. Essentially, there is a robot (circle) that starts on the blue start-point, then keeps taking steps (either with a designated policy or randomly), until it reaches the end point. Here is a simulation to demonstrate:

# %%
# Load Libraries
import numpy as np
import pandas as pd
import math
import random
import gym
import gym_maze

env = gym.make("maze-sample-5x5-v0")

# first point for ID
observation = env.reset()
offset = np.array((random.random(), random.random()))
for _ in range(1000):
    
    env.render()
    action = env.action_space.sample() # your agent here (this takes random actions)
    observation, reward, done, info = env.step(action)
      
    if done:
      observation = env.reset()
env.close()
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.7.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Algorithm Goal

# %% [markdown]
# The goal on our end is to derive our dataset from the path that the robot takes. Every time it reaches a new coordinate, depending on whether the coordinate is the goal, the robot gets a "reward." With these datapoints, our algorithm should be able to learn an MDP to map out the optimal path through the maze!

# %% [markdown]
# ## Dataset Creation

# %% [markdown]
# Loading relevant packages and functions - make sure to change the `sys.path.append` line with the relevant directory that contains the MDP Algorithm.

# %%
# Set Working Directory
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd

import sys
sys.path.append('/Users/janiceyang/Dropbox (MIT)/ORC UROP/Opioids/Algorithm/')

#from MDPtools import *
from model import MDP_model
from maze_functions import createSamples
from testing import cluster_size, next_clusters, training_value_error, purity

# %% [markdown]
# Now selecting parameters: here, we decide how many times we want the robot to run through the maze (`N`), when we want to start a new run if the robot takes too long (`T_max`), and the maze that we want the robot to run through (`mazes[x]`, with x being a number from the dictionary).
#
# `reseed`' is set to `True` if we want the robot to travel to a different location within each cell every time it moves, while `False` ensures that the robot will start at a certain place in the initial coordinate, but move to the exact same place in the next coordinate.

# %%
N = 50
T_max = 100

# list of maze options to choose from:
mazes = {1: 'maze-v0',
         2: 'maze-sample-3x3-v0',
         3: 'maze-random-3x3-v0',
         4: 'maze-sample-5x5-v0',
         5: 'maze-random-5x5-v0',
         6: 'maze-sample-10x10-v0',
         7: 'maze-random-10x10-v0',
         8: 'maze-sample-100x100-v0',
         9: 'maze-random-100x100-v0',
         10: 'maze-random-10x10-plus-v0', # has portals 
         11: 'maze-random-20x20-plus-v0', # has portals 
         12: 'maze-random-30x30-plus-v0'} # has portals 

df = createSamples(N, T_max, mazes[2], reseed=True)
print(df)
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.7.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#       ID  TIME  FEATURE_0  FEATURE_1 ACTION      RISK
# 0      0     0   0.402222   0.497286      0 -0.011111
# 1      0     1   0.392295   0.816108      3 -0.011111
# 2      0     2   0.672513   0.346026      1 -0.011111
# 3      0     3   0.816671   1.800947      0 -0.011111
# 4      0     4   0.519941   0.308363      0 -0.011111
# ...   ..   ...        ...        ...    ...       ...
# 3012  49     9   1.399846   2.723537      0 -0.011111
# 3013  49    10   1.416531   2.951786      1 -0.011111
# 3014  49    11   1.168377   2.885278      1 -0.011111
# 3015  49    12   1.317615   2.327765      2 -0.011111
# 3016  49    13   2.269221   2.013544   None  1.000000
#
# [3017 rows x 6 columns]

# %% [markdown]
# The resulting `FEATURE_0` and `FEATURE_1` are the `x` and `y` coordinates respectively, while `ACTION` corresponds to the (`N`, `S`, `W`, `E`) directions. `RISK` is a reward of `1` if the endstate goal is reached, otherwise it is a negative factor of the maze size for all other locations. The robot does not change cells if it hits a wall, but if `reseed = True`, it can still change locations within the same cell.

# %% [markdown]
# ## Running the Algorithm

# %% [markdown]
# Now, we can run the algorithm on the generated dataset! First, we can set some parameters, including `max_k` which is the number of clusters we want to end with, and thus determines the number of iterations during the splitting process. Since initial clustering is based solely on `RISK`, and there are only two groups (end state and all others), there will only be two initial clusters. The expected optimal `max_k` should be the maze size.

# %%
max_k = 11
clustering = 'Agglomerative'
n_clusters = None
distance_threshold = 0.5
random_state = 0
pfeatures = 2
actions = [0, 1, 2, 3]
h = -1
cv = 5
th = 0
classification = 'DecisionTreeClassifier'

# %% [markdown]
# Now, we can fit an algorithm model to this, using either `m.fit` or `m.fit_CV` (this one runs with `cv` rounds of cross validation, and takes the optimal split). `m.fit` with `optimize=True` will train the model on all the data, and retain the model with an optimal amount of splits.

# %%
m = MDP_model()
m.fit(df, # df: dataframe in the format ['ID', 'TIME', ...features..., 'RISK', 'ACTION']
    pfeatures, # int: number of features
    h, # int: time horizon (# of actions we want to optimize)
    max_k, # int: number of iterations
    distance_threshold, # clustering diameter for Agglomerative clustering
    cv, # number for cross validation
    th, # splitting threshold
    classification, # classification method
    clustering,# clustering method from Agglomerative, KMeans, and Birch
    n_clusters, # number of clusters for KMeans
    random_state,
    plot=True,
    optimize=True)
# Out:
# Splitting... |#Clusters:2:   0%|          | 0/9 [00:00<?, ?it/s]
# Clusters Initialized
#       ID  TIME  FEATURE_0  FEATURE_1 ACTION      RISK  CLUSTER NEXT_CLUSTER
# 0      0     0   0.402222   0.497286      0 -0.011111        0            0
# 1      0     1   0.392295   0.816108      3 -0.011111        0            0
# 2      0     2   0.672513   0.346026      1 -0.011111        0            0
# 3      0     3   0.816671   1.800947      0 -0.011111        0            0
# 4      0     4   0.519941   0.308363      0 -0.011111        0            0
# ...   ..   ...        ...        ...    ...       ...      ...          ...
# 3012  49     9   1.399846   2.723537      0 -0.011111        0            0
# 3013  49    10   1.416531   2.951786      1 -0.011111        0            0
# 3014  49    11   1.168377   2.885278      1 -0.011111        0            0
# 3015  49    12   1.317615   2.327765      2 -0.011111        0            1
# 3016  49    13   2.269221   2.013544   None  1.000000        1         None
#
# [3017 rows x 8 columns]
#                NEXT_CLUSTER
# CLUSTER ACTION
# 0       0                 0
#         1                 0
#         2                 0
#         3                 0
# 1       None           None
# 2       0                 2
#         1                 2
#         2                 1
#         3                 0
# Splitting... |#Clusters:3:  11%|█         | 1/9 [00:02<00:23,  2.94s/it]
#                NEXT_CLUSTER
# CLUSTER ACTION
# 0       0                 0
#         1                 0
#         2                 0
#         3                 0
# 1       None           None
# 2       0                 2
#         1                 2
#         2                 1
#         3                 3
# 3       0                 0
#         1                 3
#         2                 2
#         3                 3
# Splitting... |#Clusters:4:  22%|██▏       | 2/9 [00:05<00:19,  2.72s/it]
#                NEXT_CLUSTER
# CLUSTER ACTION
# 0       0                 0
#         1                 0
#         2                 0
#         3                 0
# 1       None           None
# 2       0                 2
#         1                 2
#         2                 1
#         3                 3
# 3       0                 4
#         1                 3
#         2                 2
#         3                 3
# 4       0                 0
#         1                 3
#         2                 4
#         3                 4
# Splitting... |#Clusters:5:  33%|███▎      | 3/9 [00:07<00:15,  2.57s/it]
#                NEXT_CLUSTER
# CLUSTER ACTION
# 0       0                 0
#         1                 0
#         2                 0
#         3                 0
# 1       None           None
# 2       0                 2
#         1                 2
#         2                 1
#         3                 3
# 3       0                 4
#         1                 3
#         2                 2
#         3                 3
# 4       0                 5
#         1                 3
#         2                 4
#         3                 4
# 5       0                 5
#         1                 4
#         2                 0
#         3                 5
# Splitting... |#Clusters:6:  44%|████▍     | 4/9 [00:09<00:12,  2.49s/it]
#                NEXT_CLUSTER
# CLUSTER ACTION
# 0       0                 0
#         1                 0
#         2                 0
#         3                 0
# 1       None           None
# 2       0                 2
#         1                 2
#         2                 1
#         3                 3
# 3       0                 4
#         1                 3
#         2                 2
#         3                 3
# 4       0                 5
#         1                 3
#         2                 4
#         3                 4
# 5       0                 5
#         1                 4
#         2                 6
#         3                 5
# 6       0                 6
#         1                 6
#         2                 0
#         3                 5
# Splitting... |#Clusters:7:  56%|█████▌    | 5/9 [00:12<00:09,  2.45s/it]
#                NEXT_CLUSTER
# CLUSTER ACTION
# 0       0                 7
#         1                 0
#         2                 0
#         3                 0
# 1       None           None
# 2       0                 2
#         1                 2
#         2                 1
#         3                 3
# 3       0                 4
#         1                 3
#         2                 2
#         3                 3
# 4       0                 5
#         1                 3
#         2                 4
#         3                 4
# 5       0                 5
#         1                 4
#         2                 6
#         3                 5
# 6       0                 6
#         1                 6
#         2                 7
#         3                 5
# 7       0                 7
#         1                 0
#         2                 7
#         3                 6
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 54
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 55
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 56
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 57
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 58
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 59
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 60
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 61
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 62
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 63
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 64
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 65
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 66
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 67
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 68
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 69
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 70
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 71
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 72
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 73
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 74
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 75
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 76
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 77
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 78
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 79
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 80
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 81
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 82
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 83
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 84
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 85
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 86
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 87
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 88
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 89
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 90
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 91
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 92
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 93
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 94
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 95
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 96
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 97
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 98
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 12 49
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 12 50
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 51
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 12 52
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 12 53
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 54
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 55
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 12 56
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 57
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 12 58
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 12 59
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 60
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 12 61
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 62
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 63
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 64
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 12 65
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 12 66
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 12 67
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 12 68
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 12 69
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 12 70
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 71
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 12 72
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 12 73
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 12 74
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 75
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 76
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 12 77
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 12 78
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 12 79
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 12 80
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 28 36
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 37
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 38
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 39
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 40
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 41
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 42
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 43
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 44
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 45
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 46
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 47
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 28 48
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 49
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 50
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 51
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 28 52
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 53
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 54
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 55
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 56
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 57
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 58
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 59
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 28 60
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 61
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 62
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 63
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 64
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 65
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 66
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 67
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 68
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 69
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 70
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 71
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 72
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 73
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 74
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 75
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 76
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 77
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 78
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 28 79
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 80
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 81
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 28 82
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 83
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 84
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 85
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 86
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 87
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 88
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 89
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 90
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 91
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 28 92
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 28 93
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 28 94
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 95
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 96
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 28 97
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 28 98
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 36
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 37
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 38
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 39
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 40
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 41
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 42
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 43
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 44
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 45
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 46
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 47
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 48
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 49
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 50
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 51
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 52
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 53
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 54
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 55
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 56
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 57
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 58
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 59
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 60
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 61
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 62
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 63
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 64
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 65
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 66
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 67
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 68
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 69
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 70
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 71
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 72
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 73
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 74
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 75
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 76
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 77
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 78
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 79
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 80
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 81
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 82
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 83
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 84
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 85
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 86
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 87
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 88
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 89
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 90
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 91
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 92
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 93
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 94
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 95
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 96
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 97
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 98
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 32
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 33
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 34
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 35
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 36
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 37
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 38
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 39
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 40
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 41
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 42
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 43
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 44
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 45
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 46
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 47
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 48
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 49
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 50
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 51
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 52
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 53
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 54
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 55
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 56
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 57
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 58
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 59
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 60
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 61
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 62
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 63
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 64
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 65
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 66
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 67
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 68
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 69
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 70
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 71
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 72
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 73
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 74
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 75
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 76
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 77
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 78
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 79
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 80
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 81
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 82
# WARNING: Trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 83
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 84
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 85
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 86
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 87
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 88
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 89
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 90
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 91
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 92
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 93
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 94
# WARNING: Trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 95
# WARNING: Trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 96
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 97
# WARNING: Trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 98
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 53
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 54
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 55
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 56
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 57
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 58
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 59
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 60
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 61
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 62
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 63
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 64
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 65
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 66
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 67
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 68
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 69
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 70
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 71
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 72
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 73
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 74
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 75
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 76
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 77
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 78
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 79
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 80
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 81
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 82
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 83
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 84
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 85
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 86
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 6 87
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 6 88
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 6 89
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 6 90
# ...
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 79
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 80
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 81
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 82
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 83
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 84
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 85
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 86
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 87
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 88
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 37 89
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 90
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 91
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 92
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 93
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 94
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 95
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 37 96
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 37 97
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 37 98
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 31
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 32
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 33
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 34
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 35
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 36
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 37
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 38
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 39
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 40
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 41
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 42
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 43
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 44
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 45
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 46
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 47
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 48
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 49
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 50
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 51
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 52
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 53
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 54
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 55
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 56
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 57
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 58
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 59
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 60
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 61
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 62
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 63
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 64
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 65
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 66
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 67
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 68
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 69
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 70
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 71
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 72
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 73
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 74
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 75
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 76
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 77
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 78
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 79
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 80
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 81
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 82
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 83
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 84
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 85
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 86
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 87
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 88
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 89
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 90
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 91
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 92
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 93
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 1 , but this transition is never seen in the data. Data point: 40 94
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 2 , but this transition is never seen in the data. Data point: 40 95
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 96
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 3 , but this transition is never seen in the data. Data point: 40 97
# WARNING: In training value evaluation, trying to predict next state from state 1.0 taking action 0 , but this transition is never seen in the data. Data point: 40 98
# Splitting... |#Clusters:8:  86%|████████▌ | 6/7 [00:14<00:02,  2.57s/it]
#                NEXT_CLUSTER
# CLUSTER ACTION
# 0       0                 7
#         1                 0
#         2                 0
#         3                 8
# 1       None           None
# 2       0                 2
#         1                 2
#         2                 1
#         3                 3
# 3       0                 4
#         1                 3
#         2                 2
#         3                 3
# 4       0                 5
#         1                 3
#         2                 4
#         3                 4
# 5       0                 5
#         1                 4
#         2                 6
#         3                 5
# 6       0                 6
#         1                 6
#         2                 7
#         3                 5
# 7       0                 7
#         1                 0
#         2                 7
#         3                 6
# 8       0                 8
#         1                 8
#         2                 0
#         3                 8
# Splitting... |#Clusters:8:  86%|████████▌ | 6/7 [00:17<00:02,  2.88s/it]
# Optimal # of clusters reached
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning

# %% [markdown]
# ## Visualizing Results
